# %% [markdown]
# # CONTENT BASED FILTERING FOR MOVIE RECOMMENDATION

# %%
import pandas as pd

# %%
df = pd.DataFrame(pd.read_csv("MoviesOnStreamingPlatforms_updated.csv"))
df.head(4)
# Out:
#    Unnamed: 0  ID                   Title  Year  Age  IMDb Rotten Tomatoes  \
# 0           0   1               Inception  2010  13+   8.8             87%
# 1           1   2              The Matrix  1999  18+   8.7             87%
# 2           2   3  Avengers: Infinity War  2018  13+   8.5             84%
# 3           3   4      Back to the Future  1985   7+   8.5             96%
#
#    Netflix  Hulu  Prime Video  Disney+  Type                       Directors  \
# 0        1     0            0        0     0               Christopher Nolan
# 1        1     0            0        0     0  Lana Wachowski,Lilly Wachowski
# 2        1     0            0        0     0         Anthony Russo,Joe Russo
# 3        1     0            0        0     0                 Robert Zemeckis
#
#                              Genres                       Country  \
# 0  Action,Adventure,Sci-Fi,Thriller  United States,United Kingdom
# 1                     Action,Sci-Fi                 United States
# 2           Action,Adventure,Sci-Fi                 United States
# 3           Adventure,Comedy,Sci-Fi                 United States
#
#                   Language  Runtime
# 0  English,Japanese,French    148.0
# 1                  English    136.0
# 2                  English    149.0
# 3                  English    116.0

# %% [markdown]
# ## CLEANING DATA

# %%
df.drop(['Unnamed: 0','Type','Rotten Tomatoes'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    ID                           Title  Year  Age  IMDb  Netflix  Hulu  \
# 0   1                       Inception  2010  13+   8.8        1     0
# 1   2                      The Matrix  1999  18+   8.7        1     0
# 2   3          Avengers: Infinity War  2018  13+   8.5        1     0
# 3   4              Back to the Future  1985   7+   8.5        1     0
# 4   5  The Good, the Bad and the Ugly  1966  18+   8.8        1     0
#
#    Prime Video  Disney+                       Directors  \
# 0            0        0               Christopher Nolan
# 1            0        0  Lana Wachowski,Lilly Wachowski
# 2            0        0         Anthony Russo,Joe Russo
# 3            0        0                 Robert Zemeckis
# 4            1        0                    Sergio Leone
#
#                              Genres                       Country  \
# 0  Action,Adventure,Sci-Fi,Thriller  United States,United Kingdom
# 1                     Action,Sci-Fi                 United States
# 2           Action,Adventure,Sci-Fi                 United States
# 3           Adventure,Comedy,Sci-Fi                 United States
# 4                           Western      Italy,Spain,West Germany
#
#                   Language  Runtime
# 0  English,Japanese,French    148.0
# 1                  English    136.0
# 2                  English    149.0
# 3                  English    116.0
# 4                  Italian    161.0

# %%
df.isnull().sum()
# Out:
# ID                0
# Title             0
# Year              0
# Age            9390
# IMDb            571
# Netflix           0
# Hulu              0
# Prime Video       0
# Disney+           0
# Directors       726
# Genres          275
# Country         435
# Language        599
# Runtime         592
# dtype: int64

# %%
df['Age'] = df['Age'].str.replace('+','')
df['Age'] = df['Age'].str.replace('all','0')
median = df['Age'].median()
df['Age'] = df['Age'].fillna(median)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
mean = df['Runtime'].mean()
mean_IMDb = df['IMDb'].mean()

# %%
df['Runtime'] = df['Runtime'].fillna(mean)
df['Runtime'] = df['Runtime'].astype(int)
df['IMDb'] = df['IMDb'].fillna(mean)

# %%
df.isnull().sum()
# Out:
# ID               0
# Title            0
# Year             0
# Age              0
# IMDb             0
# Netflix          0
# Hulu             0
# Prime Video      0
# Disney+          0
# Directors      726
# Genres         275
# Country        435
# Language       599
# Runtime          0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df['Runtime'] = df['Runtime'].astype(str)
df['IMDb'] = df['IMDb'].astype(str)
df['Age'] = df['Age'].astype(str)
feat = ['Title','Age','IMDb','Directors','Genres','Country','Language','Runtime']
df1 = df[feat]
df1.head()
# Out:
#                             Title Age IMDb                       Directors  \
# 0                       Inception  13  8.8               Christopher Nolan
# 1                      The Matrix  18  8.7  Lana Wachowski,Lilly Wachowski
# 2          Avengers: Infinity War  13  8.5         Anthony Russo,Joe Russo
# 3              Back to the Future   7  8.5                 Robert Zemeckis
# 4  The Good, the Bad and the Ugly  18  8.8                    Sergio Leone
#
#                              Genres                       Country  \
# 0  Action,Adventure,Sci-Fi,Thriller  United States,United Kingdom
# 1                     Action,Sci-Fi                 United States
# 2           Action,Adventure,Sci-Fi                 United States
# 3           Adventure,Comedy,Sci-Fi                 United States
# 4                           Western      Italy,Spain,West Germany
#
#                   Language Runtime
# 0  English,Japanese,French     148
# 1                  English     136
# 2                  English     149
# 3                  English     116
# 4                  Italian     161

# %% [markdown]
# ## MAKING DATA FIT FOR CONTENT BASED FILTERING ANALYSIS

# %%
def clean_data(x):
    return str.lower(x.replace(" ",""))

# %%
for i in feat:
    df1[i] = df1[i].apply(clean_data)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df1.head(2)
# Out:
#        Title Age IMDb                     Directors  \
# 0  inception  13  8.8              christophernolan
# 1  thematrix  18  8.7  lanawachowski,lillywachowski
#
#                              Genres                     Country  \
# 0  action,adventure,sci-fi,thriller  unitedstates,unitedkingdom
# 1                     action,sci-fi                unitedstates
#
#                   Language Runtime
# 0  english,japanese,french     148
# 1                  english     136

# %%
# BOW => Bag of Words
def BOW(x):
    return x['Title'] + ' ' + x['Age'] + ' ' + x['IMDb'] + ' ' + x['Directors'] + ' ' + x['Genres'] + ' ' + x['Country'] + ' ' + x['Country'] + ' ' + x['Runtime']

# %%
df1['BOW'] = df1.apply(BOW, axis=1)
df1.head()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                       Title Age IMDb                     Directors  \
# 0                 inception  13  8.8              christophernolan
# 1                 thematrix  18  8.7  lanawachowski,lillywachowski
# 2      avengers:infinitywar  13  8.5         anthonyrusso,joerusso
# 3           backtothefuture   7  8.5                robertzemeckis
# 4  thegood,thebadandtheugly  18  8.8                   sergioleone
#
#                              Genres                     Country  \
# 0  action,adventure,sci-fi,thriller  unitedstates,unitedkingdom
# 1                     action,sci-fi                unitedstates
# 2           action,adventure,sci-fi                unitedstates
# 3           adventure,comedy,sci-fi                unitedstates
# 4                           western     italy,spain,westgermany
#
#                   Language Runtime  \
# 0  english,japanese,french     148
# 1                  english     136
# 2                  english     149
# 3                  english     116
# 4                  italian     161
#
#                                                  BOW
# 0  inception 13 8.8 christophernolan action,adven...
# 1  thematrix 18 8.7 lanawachowski,lillywachowski ...
# 2  avengers:infinitywar 13 8.5 anthonyrusso,joeru...
# 3  backtothefuture 7 8.5 robertzemeckis adventure...
# 4  thegood,thebadandtheugly 18 8.8 sergioleone we...

# %% [markdown]
# ## CREATING AND RUNNING THE FILTERING ALGORITHM

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(df1['BOW'])

cos_sim = cosine_similarity(count_matrix, count_matrix)

# %%
df1 = df1.reset_index()
indices = pd.Series(df1.index, index = df1['Title'])

# %%
import numpy as np
def get_recom(t, cos_sim=cos_sim):
    t=t.replace(' ','').lower()
    i = indices[t]
    s_scores = list(enumerate(cos_sim[i]))
    s_scores = sorted(s_scores, key=lambda x: x[1], reverse=True)
    s_scores = s_scores[1:11]
    mov_idx = [j[0] for j in s_scores]
    
    l = []
    for i in mov_idx:
        Platform = []
        l.append(df['Title'].iloc[i])
        l.append(df['IMDb'].iloc[i])
        l.append(df['Directors'].iloc[i])
        l.append(df['Genres'].iloc[i])
        if df['Netflix'].iloc[i]==1:
            Platform.append("Netflix")
        if df['Prime Video'].iloc[i]==1:
            Platform.append("Prime Videos")
        if df["Hulu"].iloc[i]==1:
            Platform.append("Hulu")
        if df["Disney+"].iloc[i]==1:
            Platform.append("Disney+")
        pl = ', '.join(map(str,Platform))
        l.append(pl)
    
    l = np.array(l)
    l = l.reshape(10,5)
    
    cols = ['Title', 'IMDb Rating', 'Directed By', 'Genre','Available on Platform']
    
    l = pd.DataFrame(data=l, columns = cols)
    return l

# %%
get_recom('Inception',cos_sim)
# Out:
#                          Title IMDb Rating         Directed By  \
# 0                Batman Begins         8.2   Christopher Nolan
# 1                      Déjà Vu         7.1          Tony Scott
# 2                    GoldenEye         7.2     Martin Campbell
# 3          Tomorrow Never Dies         6.5  Roger Spottiswoode
# 4      The World Is Not Enough         6.4       Michael Apted
# 5              Die Another Day         6.1        Lee Tamahori
# 6            Zombie Apocalypse         4.0           Nick Lyon
# 7          The Hurricane Heist         5.1           Rob Cohen
# 8              The Dark Knight         9.0   Christopher Nolan
# 9  The People That Time Forgot         5.4        Kevin Connor
#
#                                      Genre Available on Platform
# 0                         Action,Adventure                  Hulu
# 1             Action,Crime,Sci-Fi,Thriller          Prime Videos
# 2                Action,Adventure,Thriller               Netflix
# 3                Action,Adventure,Thriller               Netflix
# 4                Action,Adventure,Thriller               Netflix
# 5                Action,Adventure,Thriller               Netflix
# 6  Action,Adventure,Horror,Sci-Fi,Thriller          Prime Videos
# 7          Action,Adventure,Crime,Thriller               Netflix
# 8              Action,Crime,Drama,Thriller                  Hulu
# 9                 Adventure,Fantasy,Sci-Fi          Prime Videos

# %%
get_recom('The Matrix',cos_sim)
# Out:
#                     Title IMDb Rating                     Directed By  \
# 0     The Matrix Reloaded         7.2  Lana Wachowski,Lilly Wachowski
# 1  The Matrix Revolutions         6.8  Lana Wachowski,Lilly Wachowski
# 2       Universal Soldier         6.0                 Roland Emmerich
# 3             Future Kick         4.0                    Damian Klaus
# 4          Virtual Combat         4.2                  Andrew Stevens
# 5          Gangster World         4.2                    David Bishop
# 6            CyberTracker         3.8                   Richard Pepin
# 7          Demolition Man         6.7                 Marco Brambilla
# 8            Higher Power         5.0         Matthew Charles Santoro
# 9    Escape from New York         7.2                  John Carpenter
#
#                      Genre Available on Platform
# 0            Action,Sci-Fi               Netflix
# 1            Action,Sci-Fi               Netflix
# 2            Action,Sci-Fi                  Hulu
# 3            Action,Sci-Fi          Prime Videos
# 4            Action,Sci-Fi          Prime Videos
# 5            Action,Sci-Fi          Prime Videos
# 6            Action,Sci-Fi          Prime Videos
# 7   Action,Sci-Fi,Thriller                  Hulu
# 8   Action,Sci-Fi,Thriller                  Hulu
# 9  Action,Adventure,Sci-Fi          Prime Videos

# %%
get_recom('Mohabbatein',cos_sim)
# Out:
#                          Title IMDb Rating               Directed By  \
# 0  Dilwale Dulhania Le Jayenge         8.1             Aditya Chopra
# 1     Kabhi Khushi Kabhie Gham         7.4               Karan Johar
# 2                        Lamhe         7.4               Yash Chopra
# 3                      Chandni         6.8               Yash Chopra
# 4                    Amar Prem         8.2            Shakti Samanta
# 5           Kuch Kuch Hota Hai         7.6               Karan Johar
# 6         Mujhse Shaadi Karogi         6.7              David Dhawan
# 7            Dil Vil Pyar Vyar         5.2  Ananth Narayan Mahadevan
# 8          Rab Ne Bana Di Jodi         7.2             Aditya Chopra
# 9                       Pyaasa         8.5                 Guru Dutt
#
#                           Genre  Available on Platform
# 0                 Drama,Romance           Prime Videos
# 1         Drama,Musical,Romance                Netflix
# 2         Drama,Musical,Romance           Prime Videos
# 3         Drama,Musical,Romance           Prime Videos
# 4         Drama,Musical,Romance           Prime Videos
# 5  Comedy,Drama,Musical,Romance                Netflix
# 6  Comedy,Drama,Musical,Romance  Netflix, Prime Videos
# 7         Drama,Musical,Romance  Netflix, Prime Videos
# 8    Comedy,Drama,Music,Romance           Prime Videos
# 9         Drama,Musical,Romance           Prime Videos

# %%
get_recom('Avengers: Infinity War',cos_sim)
# Out:
#                                  Title IMDb Rating              Directed By  \
# 0                    Avengers: Endgame         8.4  Anthony Russo,Joe Russo
# 1           Captain America: Civil War         7.8  Anthony Russo,Joe Russo
# 2  Captain America: The Winter Soldier         7.7  Anthony Russo,Joe Russo
# 3              Avengers: Age of Ultron         7.3              Joss Whedon
# 4                                 2012         5.8          Roland Emmerich
# 5                         The Avengers         8.0              Joss Whedon
# 6                           Iron Man 2         7.0              Jon Favreau
# 7                        Black Panther         7.3             Ryan Coogler
# 8                           Iron Man 3         7.2              Shane Black
# 9                          John Carter         6.6           Andrew Stanton
#
#                               Genre  Available on Platform
# 0     Action,Adventure,Drama,Sci-Fi                Disney+
# 1           Action,Adventure,Sci-Fi                Disney+
# 2  Action,Adventure,Sci-Fi,Thriller                Disney+
# 3           Action,Adventure,Sci-Fi                Disney+
# 4           Action,Adventure,Sci-Fi                Netflix
# 5           Action,Adventure,Sci-Fi  Prime Videos, Disney+
# 6           Action,Adventure,Sci-Fi  Prime Videos, Disney+
# 7           Action,Adventure,Sci-Fi                Disney+
# 8           Action,Adventure,Sci-Fi                Disney+
# 9           Action,Adventure,Sci-Fi                Disney+

# %%
get_recom('The Conjuring', cos_sim)
# Out:
#                     Title IMDb Rating        Directed By  \
# 0                     Cam         5.9   Daniel Goldhaber
# 1          Velvet Buzzsaw         5.7         Dan Gilroy
# 2               The Super         5.9       Stephan Rick
# 3       Chernobyl Diaries         5.0     Bradley Parker
# 4                The Doll         5.3          James Wan
# 5                 The Den         6.0    Zachary Donohue
# 6   Body at Brighton Rock         5.3   Roxanne Benjamin
# 7  The Poughkeepsie Tapes         6.1  John Erick Dowdle
# 8  Friday the 13th Part 2         6.1        Steve Miner
# 9                   Braid         5.3      Mitzi Peirone
#
#                      Genre Available on Platform
# 0  Horror,Mystery,Thriller               Netflix
# 1  Horror,Mystery,Thriller               Netflix
# 2  Horror,Mystery,Thriller               Netflix
# 3  Horror,Mystery,Thriller               Netflix
# 4  Horror,Mystery,Thriller               Netflix
# 5  Horror,Mystery,Thriller                  Hulu
# 6  Horror,Mystery,Thriller                  Hulu
# 7  Horror,Mystery,Thriller          Prime Videos
# 8  Horror,Mystery,Thriller          Prime Videos
# 9  Horror,Mystery,Thriller          Prime Videos
